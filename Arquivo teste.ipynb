# %%
import pandas as pd

# %% [markdown]
# vendas = {'produtos':['melancia', 'mamao'],'quantidade':[2, 4],'valor':[12, 14], 'marca':['bradesco','consul']}
# vendas_tabela = pd.DataFrame(vendas)
# print(vendas_tabela)
# display(vendas_tabela)

# %%
df = pd.read_excel("C:\\Users\\Asus\\Documents\\porto_galinhas.xlsx")
df
# Out:
#     Unnamed: 0  Código     Posto              Mês/Ano  Precipitação  \
# 0          NaN     387   Ipojuca  2017-07-01 00:00:00         496.8
# 1          NaN     387   Ipojuca  2017-08-01 00:00:00          55.5
# 2          NaN     387   Ipojuca  2017-09-01 00:00:00         124.7
# 3          NaN     387   Ipojuca  2017-10-01 00:00:00          40.3
# 4          NaN     387   Ipojuca  2017-11-01 00:00:00             6
# 5          NaN     387   Ipojuca  2017-12-01 00:00:00          60.9
# 6          NaN     387   Ipojuca  2018-01-01 00:00:00         130.4
# 7          NaN     387   Ipojuca  2018-02-01 00:00:00         191.3
# 8          NaN     387   Ipojuca  2018-03-01 00:00:00         242.5
# 9          NaN     387   Ipojuca  2018-04-01 00:00:00         534.4
# 10         NaN     387   Ipojuca  2018-05-01 00:00:00         221.3
# 11         NaN     387   Ipojuca  2008-06-01 00:00:00          87.3
# 12         NaN     NaN  Lockdown                  NaN           NaN
# ...

# %%
import pandas as pd
dV = pd.read_excel("C:\\Users\\Asus\\Downloads\\Vendas.xlsx")
dV = dV.head(50)
# Out:
#     Código Venda       Data                           ID Loja  \
# 0              1 2019-01-01                Iguatemi Esplanada
# 1              1 2019-01-01                Iguatemi Esplanada
# 2              1 2019-01-01                Iguatemi Esplanada
# 3              2 2019-01-02                    Norte Shopping
# 4              2 2019-01-02                    Norte Shopping
# 5              3 2019-01-02        Rio Mar Shopping Fortaleza
# 6              5 2019-01-02                    Shopping Barra
# 7              6 2019-01-02               Shopping Ibirapuera
# 8              7 2019-01-02                    Norte Shopping
# 9              7 2019-01-02                    Norte Shopping
# 10             8 2019-01-02                 Iguatemi Campinas
# 11             9 2019-01-02  Shopping Center Leste Aricanduva
# 12             9 2019-01-02  Shopping Center Leste Aricanduva
# 13            10 2019-01-02         Passei das Águas Shopping
# ...
